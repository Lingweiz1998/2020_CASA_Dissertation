# %%
from math import ceil
import pysal as ps
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PowerTransformer, RobustScaler, StandardScaler, MinMaxScaler

rbs = RobustScaler(quantile_range=[0.025,0.975])
mms = MinMaxScaler(feature_range=(0,1))
pts = PowerTransformer()
scaler = StandardScaler()

from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from esda.adbscan import ADBSCAN
from sklearn.decomposition import PCA
from geopandas import GeoDataFrame

# %%
file = 'MetroRail.geojson'
gdf = gpd.read_file(file)
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NPTREF    190 non-null    object
#  1   RSTNAM    190 non-null    object
#  2   geometry  190 non-null    geometry
# dtypes: geometry(1), object(2)
# memory usage: 4.6+ KB

# %%
df = pd.read_csv('railandmetro_merged2.csv',
                 na_values=[':'], low_memory=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NPTREF         177 non-null    object
#  1   name           177 non-null    object
#  2   near_station   177 non-null    int64
#  3   freq           177 non-null    float64
#  4   line           177 non-null    int64
#  5   bus_route      177 non-null    int64
#  6   car_park       177 non-null    int64
#  7   near_highway   177 non-null    float64
#  8   sum_pop        177 non-null    int64
#  9   sum_lab        177 non-null    int64
#  10  poi_count      177 non-null    int64
#  11  entropy        177 non-null    float64
#  12  access_lane    177 non-null    float64
#  13  bike_capacity  177 non-null    int64
#  14  intersection   177 non-null    int64
#  15  pedstrain      177 non-null    float64
#  16  ave_gmal       177 non-null    float64
#  17  dc             177 non-null    float64
#  18  cc             177 non-null    float64
#  19  bc             177 non-null    float64
#  20  prp            177 non-null    float64
#  21  greenspace     177 non-null    float64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 30.5+ KB

# %%
ppd = pd.merge(df, gdf, left_on='NPTREF', right_on='NPTREF', how='inner').reset_index()
ppd.shape
ppd.head(5)
# Out:
#    index       NPTREF          name  near_station     freq  line  bus_route  \
# 0      0  9400ZZMAABM  Abraham Moss           142   20.000     2         34
# 1      1  9400ZZMAALT    Altrincham            92  160.000     2         25
# 2      2  9400ZZMAANC     Anchorage           142    5.000     2         35
# 3      3  9100ARDWICK       ARDWICK           147    1.875     2         25
# 4      4  9100ASHBRYS      ASHBURYS           148  105.000     3         27
#
#    car_park  near_highway  sum_pop  ...  intersection  pedstrain   ave_gmal  \
# 0         2      0.029578    12574  ...             6   0.685544  11.776998
# 1        45      0.053735     6081  ...            36   0.729393  19.188176
# 2         0      0.006399     7801  ...           256   0.626876  11.258944
# 3         0      0.038448     1648  ...             6   0.427932  17.415557
# 4         0      0.057072     3239  ...            32   0.691228  14.908093
#
#     dc        cc      bc       prp  greenspace        RSTNAM  \
# 0  5.0  0.000187  3136.0  0.005116   17.347970  Abraham Moss
# 1  6.0  0.000143   372.0  0.005800   49.685360    Altrincham
# 2  3.0  0.000183   892.5  0.004980   11.977131     Anchorage
# 3  6.0  0.000219  6339.0  0.004625   39.259956       ARDWICK
# 4  9.0  0.000202  6191.0  0.007078   17.338474      ASHBURYS
#
#                     geometry
# 0  POINT (-2.23542 53.51051)
# 1  POINT (-2.34728 53.38745)
# 2  POINT (-2.28602 53.47431)
# 3  POINT (-2.21337 53.47121)
# 4  POINT (-2.19475 53.47187)
#
# [5 rows x 25 columns]

# %%
ppd = GeoDataFrame(ppd)

def replace_legend_items(legend, mapping):
    for txt in legend.texts:
        for k,v in mapping.items():
            if txt.get_text() == str(k):
                txt.set_text(v)

tfont = {'fontname':'Liberation Sans Narrow', 'horizontalalignment':'left'}

# %%
f = plt.figure()
f.set_size_inches(12,7)

ax1 = f.add_subplot()
ppd.plot(column='greenspace', legend=True, cmap='plasma', figsize=(12,6), ax=ax1)

f.subplots_adjust(top=0.92)
f.suptitle(f"Resident around train station", x=0.025, size=24, **tfont);

# %%
to_cluster = ppd[['NPTREF','near_station','freq','line','bus_route','bike_capacity','car_park','near_highway','sum_pop','sum_lab','entropy','poi_count',
                 'access_lane','intersection','pedstrain','dc','cc','bc','greenspace']].set_index('NPTREF').copy()
to_cluster.head()
# Out:
#              near_station     freq  line  bus_route  bike_capacity  car_park  \
# NPTREF
# 9400ZZMAABM           142   20.000     2         34              0         2
# 9400ZZMAALT            92  160.000     2         25             58        45
# 9400ZZMAANC           142    5.000     2         35             16         0
# 9100ARDWICK           147    1.875     2         25              0         0
# 9100ASHBRYS           148  105.000     3         27              0         0
#
#              near_highway  sum_pop  sum_lab   entropy  poi_count  access_lane  \
# NPTREF
# 9400ZZMAABM      0.029578    12574     3591  1.250721         20     3.557799
# 9400ZZMAALT      0.053735     6081     3258  0.416671        138     1.007778
# 9400ZZMAANC      0.006399     7801     4490  0.838144        225     2.980509
# 9100ARDWICK      0.038448     1648      472  2.157234         21     3.462621
# 9100ASHBRYS      0.057072     3239      980 -1.748754         13     2.330456
#
#              intersection  pedstrain   dc        cc      bc  greenspace
# NPTREF
# 9400ZZMAABM             6   0.685544  5.0  0.000187  3136.0   17.347970
# 9400ZZMAALT            36   0.729393  6.0  0.000143   372.0   49.685360
# 9400ZZMAANC           256   0.626876  3.0  0.000183   892.5   11.977131
# 9100ARDWICK             6   0.427932  6.0  0.000219  6339.0   39.259956
# 9100ASHBRYS            32   0.691228  9.0  0.000202  6191.0   17.338474

# %%
network_data = ppd[['NPTREF','dc','cc','bc','greenspace']].set_index('NPTREF').copy()
network_data.head()
# Out:
#               dc        cc      bc  greenspace
# NPTREF
# 9400ZZMAABM  5.0  0.000187  3136.0   17.347970
# 9400ZZMAALT  6.0  0.000143   372.0   49.685360
# 9400ZZMAANC  3.0  0.000183   892.5   11.977131
# 9100ARDWICK  6.0  0.000219  6339.0   39.259956
# 9100ASHBRYS  9.0  0.000202  6191.0   17.338474

# %%
to_cluster.describe()
# Out:
#        near_station        freq        line   bus_route  bike_capacity  \
# count    177.000000  177.000000  177.000000  177.000000     177.000000
# mean     109.570621   43.359463    2.169492   30.468927      97.237288
# std       38.833954   52.791207    0.956186   17.451895     313.922164
# min       13.000000    1.875000    1.000000    1.000000       0.000000
# 25%       94.000000   10.000000    2.000000   21.000000       0.000000
# 50%      122.000000   25.000000    2.000000   28.000000      16.000000
# 75%      139.000000   60.000000    2.000000   36.000000      50.000000
# max      152.000000  310.000000    9.000000  110.000000    2644.000000
#
#           car_park  near_highway       sum_pop      sum_lab     entropy  \
# count   177.000000    177.000000    177.000000   177.000000  177.000000
# mean     42.259887      0.023463   5707.118644  2603.711864    1.219487
# std     112.028153      0.015797   3298.246291  1608.507157    2.306460
# min       0.000000      0.001885      0.000000     0.000000   -6.495189
# 25%       0.000000      0.012501   3364.000000  1340.000000    0.677120
# 50%       0.000000      0.019238   5754.000000  2536.000000    1.089299
# 75%      32.000000      0.030678   7483.000000  3480.000000    1.274947
# max    1000.000000      0.084481  17688.000000  8561.000000   22.401314
#
#          poi_count  access_lane  intersection   pedstrain          dc  \
# count   177.000000   177.000000    177.000000  177.000000  177.000000
# mean     77.875706     3.597380     33.282486    0.651624    7.971751
# std     178.525228     2.365756     53.787771    0.119488    9.344681
# min       1.000000     0.000000      0.000000    0.149411    2.000000
# 25%      10.000000     1.811969      4.000000    0.591350    4.000000
# 50%      20.000000     3.150600     13.000000    0.668898    5.000000
# 75%      50.000000     5.111205     38.000000    0.731423    7.000000
# max    1107.000000     9.914807    334.000000    0.876976   84.000000
#
#                cc            bc     greenspace
# count  177.000000    177.000000     177.000000
# mean     0.000158   2204.841808    4860.672098
# std      0.000039   2591.487802   44028.181101
# min      0.000090      0.000000       0.000000
# 25%      0.000127    623.000000      15.276332
# 50%      0.000155   1542.500000      28.068172
# 75%      0.000184   2758.000000      59.772271
# max      0.000260  19455.500000  564458.810100

# %%
df_analyse_histograms = to_cluster.hist(figsize = (20,12))

# %%
normed = to_cluster.copy()
for c in to_cluster.columns.values:
    normed[c] = pts.fit_transform(to_cluster[c].values.reshape(-1,1))
normed.sample(5)
# Out:
#              near_station      freq      line  bus_route  bike_capacity  \
# NPTREF
# 9400ZZMACRN      1.004184  0.856774  1.167671  -0.108057       0.719236
# 9400ZZMATRC      0.236385 -1.631544 -2.230955   0.276162      -1.163892
# 9100BAGE         0.801488  0.856774 -0.004382  -0.177830       0.679892
# 9400ZZMABAG     -0.038639 -0.918042 -0.004382   0.505538       0.771661
# 9400ZZMACEM      1.129241 -0.918042 -0.004382   0.666299       0.877961
#
#              car_park  near_highway   sum_pop   sum_lab   entropy  poi_count  \
# NPTREF
# 9400ZZMACRN -0.809067     -0.417452  1.271627  1.531260 -0.008742   0.686649
# 9400ZZMATRC -0.809067     -1.462346 -2.536329 -2.464582  0.165888   0.524057
# 9100BAGE    -0.809067      0.055861  1.281963  1.077125 -0.294252   0.322204
# 9400ZZMABAG -0.809067      0.001457 -0.489457 -0.571167  0.297093  -1.599672
# 9400ZZMACEM -0.809067      0.405049  0.345964  0.360111  0.013782  -0.273183
#
#              access_lane  intersection  pedstrain        dc        cc  \
# NPTREF
# 9400ZZMACRN     1.445553      1.673762  -1.462092  0.918813  1.944928
# 9400ZZMATRC     1.649925      1.576141  -1.778523 -2.802253 -0.382977
# 9100BAGE       -1.279523      0.594812   0.434568 -0.137022  0.870912
# 9400ZZMABAG     0.017296      0.714888  -0.863195 -0.667642 -0.666453
# 9400ZZMACEM    -0.314968     -0.561833   0.580238 -0.137022 -0.191416
#
#                    bc  greenspace
# NPTREF
# 9400ZZMACRN  2.252579   -0.964502
# 9400ZZMATRC -1.980306    2.702460
# 9100BAGE     0.334287    0.070558
# 9400ZZMABAG  0.701916    0.275958
# 9400ZZMACEM  0.010908    0.611529

# %%
normnetwork = network_data.copy()
for c in network_data.columns.values:
    normnetwork[c] = pts.fit_transform(network_data[c].values.reshape(-1,1))
normnetwork.sample(5)
# Out:
#                    dc        cc        bc  greenspace
# NPTREF
# 9400ZZMAEXS  0.240994  1.683729  0.260177   -1.307560
# 9400ZZMACEM -0.137022 -0.191416  0.010908    0.611529
# 9400ZZMABOW -0.667642  0.301384  0.433989    0.528796
# 9400ZZMAECC  1.703515  1.324857  0.672141    0.440257
# 9400ZZMAELN -0.137022  0.098606  0.148480    0.686917

# %%
df_analyse_histograms = normed.hist(figsize = (20,12))

# %%
fig, ax = plt.subplots(figsize=(10,8))         # Sample figsize in inches

# plotting correlation heatmap
dataplot = sns.heatmap(np.round(score_pca.corr(),2), cmap="YlGnBu", annot=True)
# displaying heatmap
plt.show()

# %%
normed.to_csv(r'normedmetrolink.csv', index = True)
normnetwork.to_csv(r'normcomparevalue.csv', index = True)

# %%
score_pca = pd.read_csv('npm1.csv',
                 na_values=[':'], low_memory=False)
score_pca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NPTREF      177 non-null    object
#  1   node        177 non-null    float64
#  2   place       177 non-null    float64
#  3   design      177 non-null    float64
#  4   greenspace  177 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
score_pca = score_pca[['NPTREF','node','place','design','greenspace']].set_index('NPTREF').copy()
score_pca.head()
# Out:
#                  node     place    design  greenspace
# NPTREF
# 9100ARDWICK  0.408175 -1.290132 -0.609224    0.280762
# 9100ASHBRYS  0.093246 -0.905981  0.177057   -0.337924
# 9100ATHERTN -1.162204 -0.009129 -1.129264   -1.417963
# 9100BAGE     0.449983  1.166825 -0.227482    0.070558
# 9100BLLVUE   0.254694  0.295715 -0.057663    0.233338

# %%
score_pca.describe()
# Out:
#                node         place        design    greenspace
# count  1.770000e+02  1.770000e+02  1.770000e+02  1.770000e+02
# mean  -1.694917e-11 -2.824861e-11  2.259891e-11 -1.129946e-11
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.002837e+00
# min   -2.603170e+00 -2.632422e+00 -2.312981e+00 -3.958733e+00
# 25%   -5.961417e-01 -6.988066e-01 -8.028834e-01 -4.423206e-01
# 50%    1.274975e-01  6.557304e-02 -4.503739e-02  3.847604e-02
# 75%    6.800634e-01  5.938484e-01  8.291261e-01  5.613462e-01
# max    2.664356e+00  2.391832e+00  2.012096e+00  2.974601e+00

# %%
# calculate SSE for a range of number of cluster
list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='k-means++', random_state=0)
    km.fit(score_pca)
    # inertia is a concept in physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o', linestyle = '--')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
k_cluster = 5
random_seed = 1
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
kmeans_method.fit(score_pca)
# Out:
# KMeans(n_clusters=5, random_state=1)

# %%
score_pca['Kmeans_Cluster'] = kmeans_method.labels_
score_pca['Segement'] = score_pca['Kmeans_Cluster'].map({0:'Cluster1',1:'Cluster2',2:'Cluster3',3:'Cluster4',4:'Cluster5',5:'sixth',6:'seventh',7:'eighth'})

# %%
score_pca_merge = pd.merge(score_pca, gdf, left_on='NPTREF', right_on='NPTREF', how='inner').reset_index()
score_pca_merge.shape
score_pca_merge.head(5)
# Out:
#    index       NPTREF      node     place    design  greenspace  \
# 0      0  9100ARDWICK  0.408175 -1.290132 -0.609224    0.280762
# 1      1  9100ASHBRYS  0.093246 -0.905981  0.177057   -0.337924
# 2      2  9100ATHERTN -1.162204 -0.009129 -1.129264   -1.417963
# 3      3     9100BAGE  0.449983  1.166825 -0.227482    0.070558
# 4      4   9100BLLVUE  0.254694  0.295715 -0.057663    0.233338
#
#    Kmeans_Cluster  Segement     RSTNAM                   geometry
# 0               2  Cluster3    ARDWICK  POINT (-2.21337 53.47121)
# 1               2  Cluster3   ASHBURYS  POINT (-2.19475 53.47187)
# 2               3  Cluster4   ATHERTON  POINT (-2.47799 53.52911)
# 3               1  Cluster2    BURNAGE  POINT (-2.21523 53.42196)
# 4               1  Cluster2  BELLE VUE  POINT (-2.18019 53.46179)

# %%
score_pca_merge = GeoDataFrame(score_pca_merge)

# %%
score_pca_merge.plot(column='Kmeans_Cluster', categorical=True, legend=True, figsize=(12,8));

# %%
plot_norm = sns.pairplot(score_pca,hue = 'Segement',height = 2,palette = 'Set1')
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
score_pca_merge.to_csv(r'clusterresult2.csv', index = True)
